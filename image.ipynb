# %%
#binary image
import cv2

# read the image file
img = cv2.imread('im.jpg', 2)

ret, bw_img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# converting to its binary form
bw = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

cv2.imshow("Binary", bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import Image
image = Image.open('im.jpg')
image.show()

# %%
#image attributes
from PIL import Image
print("FileName: ", image.filename)
print("Mode: ", image.mode)
print("size: ", image.size)
print("Format: ", image.format)
print("Width: ", image.width)
print("Height: ", image.height)
image.close()
# Out:
# FileName:  im.jpg
# Mode:  RGB
# size:  (1024, 610)
# Format:  JPEG
# Width:  1024
# Height:  610

# %%
# converting one format image into another format
from PIL import Image
image = Image.open('im.jpg')
image = image.convert("RGB")
image.save("converted-png-im.png")
print("image successfully converted")
# Out:
# image successfully converted

# %%
#cropping an image
import cv2
image = cv2.imread(r"D:\image processing\im.jpg")

y=0
x=0
h=600
w=810
crop_image = image[x:w, y:h]
cv2.imshow("Cropped", crop_image)
cv2.waitKey(0)
# Out:
# -1

# %%
#cropped image
from PIL import Image

#Create an Image Object from an Image
im = Image.open('D:\image processing\im.jpg')

#Display actual image
im.show()

#left, upper, right, lowe
#Crop
cropped = im.crop((1,2,300,300))

#Display the cropped portion
cropped.show()

#Save the cropped image
cropped.save('D:\image processing\croppedBeach1.jpg')

# %%
from PIL import Image, ImageOps

im = Image.open('D:/image processing/im.jpg')
im_invert = ImageOps.invert(im)
im_invert.save('D:/image processing/negation.jpg', quality=95)
im_invert.show('negative',im)

# %%
#blending
from PIL import Image

# Function to change the image size
def changeImageSize(maxWidth,
                    maxHeight,
                    image):
   
    widthRatio  = maxWidth/image.size[0]
    heightRatio = maxHeight/image.size[1]

    newWidth    = int(widthRatio*image.size[0])
    newHeight   = int(heightRatio*image.size[1])

    newImage    = image.resize((newWidth, newHeight))
    return newImage
   
# Take two images for blending them together  
image1 = Image.open("rose.jpg")
image2 = Image.open("ros.jpg")

# Make the images of uniform size
image3 = changeImageSize(800, 500, image1)
image4 = changeImageSize(800, 500, image2)

# Make sure images got an alpha channel
image5 = image3.convert("RGBA")
image6 = image4.convert("RGBA")

# Display the images
image5.show()
image6.show()

# alpha-blend the images with varying values of alpha
alphaBlended1 = Image.blend(image5, image6, alpha=.2)
alphaBlended2 = Image.blend(image5, image6, alpha=.4)

# Display the alpha-blended images
alphaBlended1.show()
alphaBlended2.show()

# %%
#histogram
import matplotlib.pyplot as plt
import cv2

im = cv2.imread('im.jpg')
# calculate mean value from RGB channels and flatten to 1D array
vals = im.mean(axis=2).flatten()
# plot histogram with 255 bins
b, bins, patches = plt.hist(vals, 255)
plt.xlim([0,255])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('im.jpg')
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow('original image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
canvas = np.zeros ((300, 300, 3), dtype="uint8")

# %%
green = (0, 255, 0)
cv2.line(canvas, (0, 0), (300, 300), green)
cv2.imshow("Canvas", canvas)
cv2.waitKey(0)

red = (0, 0, 255)
cv2.line(canvas, (300, 0), (0, 300), red, 3)
cv2.imshow("Canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
#rgb colors
import matplotlib.pyplot as plt
im1=Image.open("rgb1.jpg")
ch_r,ch_g,ch_b=im1.split()
plt.figure(figsize=(18,6))
plt.subplot(1,3,1);
plt.imshow(ch_r,cmap=plt.cm.Reds);plt.axis('off')
plt.subplot(1,3,2);
plt.imshow(ch_g,cmap=plt.cm.Greens);plt.axis('off')
plt.subplot(1,3,3);
plt.imshow(ch_b,cmap=plt.cm.Blues);plt.axis('off')
plt.tight_layout()
plt.show()

# %%
from PIL import Image
img = Image.open('im.jpg')
img.save("D:/im.tiff",'TIFF')


import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.camera()  
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image, cmap='gray')

# %%
from PIL import Image
img = Image.open('im.jpg')
img.save("D:/im.tiff",'TIFF')


import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.clock()  
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image, cmap='gray')

# %%
from PIL import Image
img = Image.open('im.jpg')
img.save("D:/im.tiff",'TIFF')


import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.coins()  
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image, cmap='gray')
